# %%
import networkx as nx
# %matplotlib inline

# %%
net = nx.read_graphml("data/florentine.graphml")

# %%
nx.draw(net, with_labels=True)

# %%
nx.cliques_containing_node(net)
# Out:
# {'Acciaiuoli': [['Medici', 'Acciaiuoli']],
#  'Medici': [['Medici', 'Albizzi'],
#   ['Medici', 'Salviati'],
#   ['Medici', 'Acciaiuoli'],
#   ['Medici', 'Barbadori'],
#   ['Medici', 'Ridolfi', 'Tornabuoni']],
#  'Castellani': [['Castellani', 'Peruzzi', 'Strozzi'],
#   ['Castellani', 'Barbadori']],
#  'Peruzzi': [['Castellani', 'Peruzzi', 'Strozzi'],
#   ['Bischeri', 'Peruzzi', 'Strozzi']],
#  'Strozzi': [['Castellani', 'Peruzzi', 'Strozzi'],
#   ['Bischeri', 'Peruzzi', 'Strozzi'],
#   ['Strozzi', 'Ridolfi']],
#  'Barbadori': [['Castellani', 'Barbadori'], ['Medici', 'Barbadori']],
#  'Ridolfi': [['Medici', 'Ridolfi', 'Tornabuoni'], ['Strozzi', 'Ridolfi']],
#  'Tornabuoni': [['Guadagni', 'Tornabuoni'],
#   ['Medici', 'Ridolfi', 'Tornabuoni']],
#  'Albizzi': [['Guadagni', 'Albizzi'],
#   ['Ginori', 'Albizzi'],
#   ['Medici', 'Albizzi']],
#  'Salviati': [['Medici', 'Salviati'], ['Pazzi', 'Salviati']],
#  'Pazzi': [['Pazzi', 'Salviati']],
#  'Bischeri': [['Guadagni', 'Bischeri'], ['Bischeri', 'Peruzzi', 'Strozzi']],
#  'Guadagni': [['Guadagni', 'Tornabuoni'],
#   ['Guadagni', 'Lamberteschi'],
#   ['Guadagni', 'Bischeri'],
#   ['Guadagni', 'Albizzi']],
#  'Ginori': [['Ginori', 'Albizzi']],
#  'Lamberteschi': [['Guadagni', 'Lamberteschi']]}

# %% [markdown]
# ## Community structure

# %%
from networkx.algorithms import community
communities = community.greedy_modularity_communities(net)
communities
# Out:
# [frozenset({'Acciaiuoli',
#             'Medici',
#             'Pazzi',
#             'Ridolfi',
#             'Salviati',
#             'Tornabuoni'}),
#  frozenset({'Barbadori', 'Bischeri', 'Castellani', 'Peruzzi', 'Strozzi'}),
#  frozenset({'Albizzi', 'Ginori', 'Guadagni', 'Lamberteschi'})]

# %%
nx.draw(net, with_labels=True)
